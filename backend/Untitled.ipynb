# %%
import os

os.makedirs("stress_app", exist_ok=True)

# %%
import shutil

shutil.move("stress_app", "Sleep analysis/stress_model.pkl")
# Out:
# 'Sleep analysis/stress_model.pkl'

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\ayash\\stress_app'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'stress_app', 'Untitled.ipynb']

# %%
import joblib
model = joblib.load("final_model.pkl")

# %%
type(model)
# Out:
# sklearn.pipeline.Pipeline

# %%
print(model)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['Age', 'Daily_Phone_Hours', 'Social_Media_Hours',
#        'Work_Productivity_Score', 'Sleep_Hours', 'App_Usage_Count',
#        'Caffeine_Intake_Cups', 'Weekend_Screen_Time_Hours'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['Gender', 'Occupation', 'Device_Type'], dtype='object'))])),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced',
#                                         n_estimators=200, random_state=42))])

# %%
import pandas as pd

sample = pd.DataFrame([{
    "Age": 25,
    "Gender": "Male",
    "Occupation": "Student",
    "Device_Type": "Android",
    "Daily_Phone_Hours": 6,
    "Social_Media_Hours": 3,
    "Work_Productivity_Score": 6,
    "Sleep_Hours": 5,
    "App_Usage_Count": 40,
    "Caffeine_Intake_Cups": 3,
    "Weekend_Screen_Time_Hours": 8
}])

# %%
model.predict(sample)
# Out:
# array(['Normal'], dtype=object)

# %%
model.named_steps["preprocessor"].transformers_[1][1].categories_
# Out:
# [array(['Female', 'Male', 'Other'], dtype=object),
#  array(['Business Owner', 'Freelancer', 'Professional', 'Student'],
#        dtype=object),
#  array(['Android', 'iOS'], dtype=object)]

# %%
import pandas as pd

sample = pd.DataFrame([{
  "Age": 25,
  "Gender": "Female",
  "Occupation": "Student",
  "Device_Type": "Android",
  "Daily_Phone_Hours": 11,
  "Social_Media_Hours": 2,
  "Work_Productivity_Score": 1,
  "Sleep_Hours": 2,
  "App_Usage_Count": 10,
  "Caffeine_Intake_Cups": 4,
  "Weekend_Screen_Time_Hours": 12
}])

# %%
model.predict(sample)
# Out:
# array(['High'], dtype=object)

# %%
import joblib
model = joblib.load("final_model.pkl")

print(model.classes_)
# Out:
# ['High' 'Normal']

# %%
import pandas as pd
df = pd.read_csv("Sleep analysis/stress_model.")  # use your actual filename/path

print(df.columns.tolist())
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("Sleep analysis/stress_model.")  # use your actual filename/path
#       4 print(df.columns.tolist())
#       5 print(df.head())
#
# ...
